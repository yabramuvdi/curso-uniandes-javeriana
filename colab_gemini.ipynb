# %% [markdown]
# # **Herramientas de IA para generación código**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/yabramuvdi/curso-uniandes-javeriana/blob/main/colab_gemini.ipynb)
#
# <br>
#
# *Curso para investigadores de la Universidad de los Andes y la Pontificia Universidad Javeriana.*
#
# Preparado por: [Yabra Muvdi](https://www.yabra.co/)
#
# <br>
#
# <p align="left">
#   <a href="https://www.linkedin.com/in/yabra-muvdi" target="_blank">
#     <img
#       src="https://upload.wikimedia.org/wikipedia/commons/c/ca/LinkedIn_logo_initials.png"
#       alt="LinkedIn"
#       width="40" height="40"
#     >
#   </a>
#   &nbsp;&nbsp;
#   <a href="https://yabra.substack.com" target="_blank">
#     <img
#       src="https://upload.wikimedia.org/wikipedia/commons/9/9a/Substack_logo.png"
#       alt="Substack (Loras Mojadas)"
#       width="250" height="40"
#     >
#   </a>
# </p>
#
#
#
# -------

# %% [markdown]
# # 0. Preparativos

# %%
# instalación de librerías (reiniciar sesión después de la instalación)
# !pip install -U datasets huggingface_hub fsspec

# %%
from datasets import load_dataset
import pandas as pd

# %%
# importo los datos de HuggingFace
ds = load_dataset("yabramuvdi/NoticiasColombia", "default", split="train")
ds
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:86: UserWarning:
# Access to the secret `HF_TOKEN` has not been granted on this notebook.
# You will not be requested again.
# Please restart the session if you want to be prompted again.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# noticias_colombia.parquet:   0%|          | 0.00/126M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/91749 [00:00<?, ? examples/s]
# Dataset({
#     features: ['id', 'texto', 'fuente', 'fecha'],
#     num_rows: 91749
# })

# %%
# transformo los datos en un dataframe de pandas
df = ds.to_pandas()
df.head()
# Out:
#    id                                              texto            fuente  \
# 0   0  Capturan a presuntos responsables de atentados...  www.eltiempo.com
# 1   1  Cambio Radical les retirará el aval a 70 candi...  www.eltiempo.com
# 2   2  Disponen de más espacio para reeducación de me...  www.eltiempo.com
# 3   3  Colombia registra cifras de ventas de vehículo...  www.eltiempo.com
# 4   4  Escondida en preservativos , CTI halló cocaína...  www.eltiempo.com
#
#                  fecha
# 0  2011-07-25 05:00:00
# 1  2011-07-25 05:00:00
# 2  2011-07-25 05:00:00
# 3  2011-07-25 05:00:00
# 4  2011-07-25 05:00:00

# %%
print(df.loc[0, "texto"])
# Out:
# Capturan a presuntos responsables de atentados en el norte del Cauca
#
# Entre los detenidos hay dos menores de edad que serían guerrilleros .
#
# Los operativos realizados por Comandos Jungla de la Policía Nacional y Fuerzas Especiales del Ejército , se registraron en zona rural del municipio de Caloto , norte del Cauca .
# Se conoció que los capturados serían integrantes de la principal estructura del Frente Sexto de las Farc , encargada de la seguridad de los cabecillas del Estado Mayor de esta guerrilla .
# El grigadier general Orlando Pineda , Comandante de la Región de Policía Número 4 , señaló que " las personas que se capturaron son las responsables de los ataques a las poblaciones de Toribío , Corinto y otras el pasado 9 de julio " , día en el que 93 personas fueron heridas y más de 400 casas resultaron averiadas .
# ...

# %% [markdown]
# # 1. Ejemplo
#
# Para darnos una mejor idea de los datos, sería interesante graficar la cantidad de artículos que fueron publicados en cada año. Vamos a hacer eso usando Gemini.

# %%
# [INSTRUCTOR] Generar gráfica con Gemini

# %% [markdown]
# # 2. Ejercicio práctico
#
# Usando Gemini, ahora les propongo una tarea más avanzada de dos partes:
#
# 1. Contar las veces que se usa la palabra "conflicto" en cada artículo
# 2. Hacer una gráfica que muestre el porcentaje de artículos que mencionan esta palabra para cada año
#
# Les sugiero hacer las dos partes por separado aunque seguramente hay una forma de hacerlo todo con una sola instrucción.

# %%
# [ESTUDIANTES]

# %% [markdown]
# # 3. Ejercicio extra
#
# Si les alcanza el tiempo (o quieren hacerlo después de la clase), otro ejercicio interesante con estos datos es el siguiente:
#
# 1. Encontrar las 20 palabras más comunes en todo el corpus
# 2. Hacer una nube de palabras

# %%
# [ESTUDIANTES]
